# %%
import pandas as pd

df= pd.read_csv("xAPI-Edu-Data.csv")
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df_girls = df[df["gender"]=="F"]
df_girls.head()
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 5       F          KW       KuwaIT    lowerlevel    G-04         A    IT
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 14      F          KW       KuwaIT  MiddleSchool    G-08         A  Math
# 15      F          KW       KuwaIT  MiddleSchool    G-06         A    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 5         F   Father           42                30                 13
# 8         F   Father           12                21                 16
# 9         F   Father           70                80                 25
# 14        F      Mum           62                70                 44
# 15        F   Father           30                40                 22
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df_boys = df[df["gender"]=="M"]
df_boys.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df_tech = df[df["Topic"]=="IT"]
df_tech.head(30)
df_tech.plot()

# %%
df_RaisedHands = pd.DataFrame(df,columns=['gender','raisedhands', 'StudentAbsenceDays'])
df_RaisedHands.head(20)
# Out:
#    gender  raisedhands StudentAbsenceDays
# 0       M           15            Under-7
# 1       M           20            Under-7
# 2       M           10            Above-7
# 3       M           30            Above-7
# 4       M           40            Above-7
# 5       F           42            Above-7
# 6       M           35            Above-7
# 7       M           50            Under-7
# 8       F           12            Under-7
# 9       F           70            Under-7
# 10      M           50            Under-7
# 11      M           19            Under-7
# 12      M            5            Above-7
# 13      M           20            Above-7
# 14      F           62            Above-7
# 15      F           30            Under-7
# 16      M           36            Above-7
# 17      M           55            Above-7
# 18      F           69            Under-7
# 19      M           70            Under-7

# %%
df_RaisedHands.groupby("gender").mean()
# Out:
#         raisedhands
# gender
# F         52.862857
# M         43.281967

# %%
df_RaisedHands.groupby("gender").mean().plot.bar()
